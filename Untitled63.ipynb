# %% [markdown]
# <a href="https://colab.research.google.com/github/hatimdeve/python/blob/main/Untitled63.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Get GPU name
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-6e3263a7-eb38-3448-c8a7-5803780dc10b)

# %%
# Note: As of May 2023, there have been some issues with TensorFlow versions 2.9-2.12
# with the following code. 
# However, these seemed to have been fixed in version 2.13+.
# TensorFlow version 2.13 is available in tf-nightly as of May 2023 (will be default in Google Colab soon).
# Therefore, to prevent errors we'll install tf-nightly first.
# See more here: https://github.com/mrdbourke/tensorflow-deep-learning/discussions/550 

# Install tf-nightly (required until 2.13.0+ is the default in Google Colab)
# !pip install -U -q tf-nightly

# Check TensorFlow version (should be minimum 2.4.0+ but 2.13.0+ is better)
import tensorflow as tf
print(f"TensorFlow version: {tf.__version__}")

# Add timestamp
import datetime
print(f"Notebook last run (end-to-end): {datetime.datetime.now()}")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.0/488.0 MB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 86.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 93.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 441.0/441.0 kB 42.9 MB/s eta 0:00:00
# TensorFlow version: 2.14.0-dev20230524
# Notebook last run (end-to-end): 2023-05-24 19:36:11.891710

# %%
# Get helper functions file
import os 

if not os.path.exists("helper_functions.py"):
    # !wget https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/extras/helper_functions.py
else:
    print("[INFO] 'helper_functions.py' already exists, skipping download.")
# Out:
# --2023-05-24 19:36:54--  https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/extras/helper_functions.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10246 (10K) [text/plain]
# Saving to: ‘helper_functions.py’
#
# helper_functions.py 100%[===================>]  10.01K  --.-KB/s    in 0s
#
# 2023-05-24 19:36:54 (101 MB/s) - ‘helper_functions.py’ saved [10246/10246]

# %%
# Import series of helper functions for the notebook (we've created/used these in previous notebooks)
from helper_functions import create_tensorboard_callback, plot_loss_curves, compare_historys,walk_through_dir

# %%
from google.colab import drive
drive.mount("/content/Drive")
# Out:
# Mounted at /content/Drive

# %%
path = "/content/Drive/MyDrive/my_dataset/"

# %%
# Create training and test directories
train_dir = "/content/Drive/MyDrive/my_dataset/CNN_project/train/"
test_dir = "/content/Drive/MyDrive/my_dataset/CNN_project/test/"

# %%
# How many images/classes are there?
walk_through_dir(path)
# Out:
# There are 1 directories and 0 images in '/content/Drive/MyDrive/my_dataset/'.
# There are 2 directories and 1 images in '/content/Drive/MyDrive/my_dataset/CNN_project'.
# There are 67 directories and 0 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test'.
# There are 0 directories and 54 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/winecellar'.
# There are 0 directories and 102 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/warehouse'.
# There are 0 directories and 30 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/waitingroom'.
# There are 0 directories and 70 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/toystore'.
# There are 0 directories and 24 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/shoeshop'.
# There are 0 directories and 31 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/stairscase'.
# There are 0 directories and 22 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/restaurant_kitchen'.
# There are 0 directories and 108 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/subway'.
# There are 0 directories and 31 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/trainstation'.
# There are 0 directories and 34 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/tv_studio'.
# There are 0 directories and 22 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/studiomusic'.
# There are 0 directories and 103 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/restaurant'.
# There are 0 directories and 22 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/videostore'.
# There are 0 directories and 47 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/meeting_room'.
# There are 0 directories and 34 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/museum'.
# There are 0 directories and 35 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/poolinside'.
# There are 0 directories and 29 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/nursery'.
# There are 0 directories and 22 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/office'.
# There are 0 directories and 35 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/movietheater'.
# There are 0 directories and 27 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/operating_room'.
# There are 0 directories and 35 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/mall'.
# There are 0 directories and 21 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/prisoncell'.
# There are 0 directories and 77 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/pantry'.
# There are 0 directories and 55 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/laundromat'.
# There are 0 directories and 32 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/jewelleryshop'.
# There are 0 directories and 25 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/laboratorywet'.
# There are 0 directories and 22 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/library'.
# There are 0 directories and 50 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/locker_room'.
# There are 0 directories and 92 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/inside_subway'.
# There are 0 directories and 141 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/livingroom'.
# There are 0 directories and 21 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/lobby'.
# There are 0 directories and 147 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/kitchen'.
# There are 0 directories and 26 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/kindergarden'.
# There are 0 directories and 47 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/gym'.
# There are 0 directories and 43 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/grocerystore'.
# There are 0 directories and 48 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/hairsalon'.
# There are 0 directories and 21 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/inside_bus'.
# There are 0 directories and 21 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/hospitalroom'.
# There are 0 directories and 26 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/gameroom'.
# There are 0 directories and 21 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/florist'.
# There are 0 directories and 21 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/garage'.
# There are 0 directories and 23 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/fastfood_restaurant'.
# There are 0 directories and 20 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/greenhouse'.
# There are 0 directories and 24 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/cloister'.
# There are 0 directories and 52 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/deli'.
# There are 0 directories and 69 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/corridor'.
# There are 0 directories and 22 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/clothingstore'.
# There are 0 directories and 55 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/dining_room'.
# There are 0 directories and 27 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/closet'.
# There are 0 directories and 21 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/concert_hall'.
# There are 0 directories and 26 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/dentaloffice'.
# There are 0 directories and 21 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/elevator'.
# There are 0 directories and 23 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/computerroom'.
# There are 0 directories and 76 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/bookstore'.
# There are 0 directories and 43 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/bowling'.
# There are 0 directories and 103 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/casino'.
# There are 0 directories and 36 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/church_inside'.
# There are 0 directories and 23 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/classroom'.
# There are 0 directories and 121 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/bar'.
# There are 0 directories and 40 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/bathroom'.
# There are 0 directories and 22 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/buffet'.
# There are 0 directories and 23 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/children_room'.
# There are 0 directories and 133 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/bedroom'.
# There are 0 directories and 28 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/artstudio'.
# There are 0 directories and 122 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/airport_inside'.
# There are 0 directories and 36 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/auditorium'.
# There are 0 directories and 81 images in '/content/Drive/MyDrive/my_dataset/CNN_project/test/bakery'.
# There are 67 directories and 0 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train'.
# There are 0 directories and 404 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/warehouse'.
# There are 0 directories and 217 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/winecellar'.
# There are 0 directories and 307 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/pantry'.
# There are 0 directories and 564 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/livingroom'.
# There are 0 directories and 412 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/casino'.
# There are 0 directories and 365 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/inside_subway'.
# There are 0 directories and 324 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/bakery'.
# There are 0 directories and 275 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/corridor'.
# There are 0 directories and 410 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/restaurant'.
# There are 0 directories and 529 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/bedroom'.
# There are 0 directories and 218 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/dining_room'.
# There are 0 directories and 120 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/waitingroom'.
# There are 0 directories and 132 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/tv_studio'.
# There are 0 directories and 277 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/toystore'.
# There are 0 directories and 86 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/studiomusic'.
# There are 0 directories and 122 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/trainstation'.
# There are 0 directories and 431 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/subway'.
# There are 0 directories and 124 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/stairscase'.
# There are 0 directories and 88 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/videostore'.
# There are 0 directories and 82 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/prisoncell'.
# There are 0 directories and 138 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/poolinside'.
# There are 0 directories and 108 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/operating_room'.
# There are 0 directories and 115 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/nursery'.
# There are 0 directories and 134 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/museum'.
# There are 0 directories and 92 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/shoeshop'.
# There are 0 directories and 87 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/office'.
# There are 0 directories and 85 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/restaurant_kitchen'.
# There are 0 directories and 100 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/laboratorywet'.
# There are 0 directories and 185 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/meeting_room'.
# There are 0 directories and 80 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/lobby'.
# There are 0 directories and 140 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/movietheater'.
# There are 0 directories and 220 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/laundromat'.
# There are 0 directories and 85 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/library'.
# There are 0 directories and 199 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/locker_room'.
# There are 0 directories and 140 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/mall'.
# There are 0 directories and 587 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/kitchen'.
# There are 0 directories and 169 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/grocerystore'.
# There are 0 directories and 184 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/gym'.
# There are 0 directories and 80 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/hospitalroom'.
# There are 0 directories and 190 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/hairsalon'.
# There are 0 directories and 81 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/inside_bus'.
# There are 0 directories and 100 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/kindergarden'.
# There are 0 directories and 81 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/garage'.
# There are 0 directories and 125 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/jewelleryshop'.
# There are 0 directories and 80 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/greenhouse'.
# There are 0 directories and 89 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/computerroom'.
# There are 0 directories and 104 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/dentaloffice'.
# There are 0 directories and 100 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/gameroom'.
# There are 0 directories and 80 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/elevator'.
# There are 0 directories and 206 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/deli'.
# There are 0 directories and 82 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/florist'.
# There are 0 directories and 89 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/fastfood_restaurant'.
# There are 0 directories and 81 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/concert_hall'.
# There are 0 directories and 144 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/church_inside'.
# There are 0 directories and 303 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/bookstore'.
# There are 0 directories and 96 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/cloister'.
# There are 0 directories and 90 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/classroom'.
# There are 0 directories and 84 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/clothingstore'.
# There are 0 directories and 89 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/children_room'.
# There are 0 directories and 170 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/bowling'.
# There are 0 directories and 86 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/buffet'.
# There are 0 directories and 105 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/closet'.
# There are 0 directories and 140 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/auditorium'.
# There are 0 directories and 481 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/bar'.
# There are 0 directories and 112 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/artstudio'.
# There are 0 directories and 157 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/bathroom'.
# There are 0 directories and 487 images in '/content/Drive/MyDrive/my_dataset/CNN_project/train/airport_inside'.

# %%
# View an image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random

def view_random_image(target_dir, target_class):
  # Setup target directory (we'll view images from here)
  target_folder = target_dir+target_class

  # Get a random image path
  random_image = random.sample(os.listdir(target_folder), 1)

  # Read in the image and plot it using matplotlib
  img = mpimg.imread(target_folder + "/" + random_image[0])
  plt.imshow(img)
  plt.title(target_class)
  plt.axis("off");

  print(f"Image shape: {img.shape}") # show the shape of the image

  return img

# %%
# Get the class names for our multi-class dataset
import pathlib
import numpy as np
data_dir = pathlib.Path(train_dir)
class_names = np.array(sorted([item.name for item in data_dir.glob('*')]))
print(class_names)
# Out:
# ['airport_inside' 'artstudio' 'auditorium' 'bakery' 'bar' 'bathroom'
#  'bedroom' 'bookstore' 'bowling' 'buffet' 'casino' 'children_room'
#  'church_inside' 'classroom' 'cloister' 'closet' 'clothingstore'
#  'computerroom' 'concert_hall' 'corridor' 'deli' 'dentaloffice'
#  'dining_room' 'elevator' 'fastfood_restaurant' 'florist' 'gameroom'
#  'garage' 'greenhouse' 'grocerystore' 'gym' 'hairsalon' 'hospitalroom'
#  'inside_bus' 'inside_subway' 'jewelleryshop' 'kindergarden' 'kitchen'
#  'laboratorywet' 'laundromat' 'library' 'livingroom' 'lobby' 'locker_room'
#  'mall' 'meeting_room' 'movietheater' 'museum' 'nursery' 'office'
#  'operating_room' 'pantry' 'poolinside' 'prisoncell' 'restaurant'
#  'restaurant_kitchen' 'shoeshop' 'stairscase' 'studiomusic' 'subway'
#  'toystore' 'trainstation' 'tv_studio' 'videostore' 'waitingroom'
#  'warehouse' 'winecellar']

# %%
# View a random image from the training dataset
img = view_random_image(target_dir=train_dir,
                        target_class=random.choice(class_names))
# Out:
# Image shape: (1536, 2048, 3)

# %%
# Create data inputs
import tensorflow as tf
IMG_SIZE = (224, 224) # define image size
train_data = tf.keras.preprocessing.image_dataset_from_directory(directory=train_dir,
                                                                            image_size=IMG_SIZE,
                                                                            label_mode="categorical", # what type are the labels?
                                                                            batch_size=32) # batch_size is 32 by default, this is generally a good number
test_data = tf.keras.preprocessing.image_dataset_from_directory(directory=test_dir,
                                                                           image_size=IMG_SIZE,
                                                                           label_mode="categorical")
# Out:
# Found 12447 files belonging to 67 classes.
# Found 3144 files belonging to 67 classes.

# %%
train_data
# Out:
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 67), dtype=tf.float32, name=None))>

# %%
# Turn on mixed precision training
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy(policy="mixed_float16") # set global policy to mixed precision

# %%
mixed_precision.global_policy() # should output "mixed_float16" (if your GPU is compatible with mixed precision)
# Out:
# <Policy "mixed_float16">

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense

# Create our model (a clone of model_8, except to be multi-class)
model_9 = Sequential([
  Conv2D(67, 3, activation='relu', input_shape=(224, 224, 3)),
  Conv2D(67, 3, activation='relu'),
  MaxPool2D(),
  Conv2D(67, 3, activation='relu'),
  Conv2D(67, 3, activation='relu'),
  MaxPool2D(),
  Flatten(),
  Dense(67, activation='softmax') # changed to have 10 neurons (same as number of classes) and 'softmax' activation
])

# Compile the model
model_9.compile(loss="categorical_crossentropy", # changed to categorical_crossentropy
                optimizer=tf.keras.optimizers.Adam(),
                metrics=["accuracy"])

# %%
12447/32
# Out:
# 388.96875

# %%
len(train_data)
# Out:
# 389

# %%
# Fit the model
history_9 = model_9.fit(train_data, # now 10 different classes 
                        epochs=5,
                        steps_per_epoch=len(train_data),
                        validation_data=test_data,
                        validation_steps=len(test_data))
# Out:
# Epoch 1/5
#   6/389 [..............................] - ETA: 1:06:15 - loss: 55.5208 - accuracy: 0.0156
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-c2d8f73b0a0a> in <cell line: 2>()
#       1 # Fit the model
# ----> 2 history_9 = model_9.fit(train_data, # now 10 different classes
#       3                         epochs=5,
#       4                         steps_per_epoch=len(train_data),
#       5                         validation_data=test_data,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1766                         ):
#    1767                             callbacks.on_train_batch_begin(step)
# -> 1768                             tmp_logs = self.train_function(iterator)
#    1769                             if data_handler.should_sync:
#    1770                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     818
#     819       with OptionalXlaContext(self._jit_compile):
# --> 820         result = self._call(*args, **kwds)
#     821
#     822       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     846       # In this case we have created variables on the first call, so we run the
#     847       # defunned version which is guaranteed to never create variables.
# --> 848       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     849     elif self._variable_creation_fn is not None:
#     850       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     139           args, kwargs
#     140       )
# --> 141     return concrete_function._call_flat(
#     142         filtered_flat_args, captured_inputs=concrete_function.captured_inputs
#     143     )  # pylint: disable=protected-access
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, args, captured_inputs)
#    1327         and executing_eagerly):
#    1328       # No tape is watching; skip to running the function.
# -> 1329       return self._build_call_outputs(self._inference_function(*args))
#    1330     forward_backward = self._select_forward_and_backward_functions(
#    1331         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in __call__(self, *args)
#     220         with record.stop_recording():
#     221           if self._bound_context.executing_eagerly():
# --> 222             outputs = self._bound_context.call_function(
#     223                 self.name,
#     224                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1477     cancellation_context = cancellation.context()
#    1478     if cancellation_context is None:
# -> 1479       outputs = execute.execute(
#    1480           name.decode("utf-8"),
#    1481           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
